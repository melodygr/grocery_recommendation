# %% [markdown]
# # Full credit to Alex Ellman
# from his blog at https://towardsdatascience.com/creating-a-grocery-product-recommender-for-instacart-c1b6bdf5ae13.  He created the functions for creating the Association Rules and they were so clean and well organized I couldn't imagine rewriting them myself.
#
# I have used his functions with very little changes except to some of the variable names, print statements, and comments.  We do have differing output because I had clustered my users slightly differently and created 20 clusters instead of his 6.

# %% [markdown]
# ## Dataset information

# %% [markdown]
# This data was retrieved from Kaggle and was provided by Instacart for a market basket analysis competition in 2018.
#
# The data is divided into 6 files:
#
# - **_Aisles.csv_**: 134 Unique aisle numbers and descriptions
# - **_Departments.csv_**: 21 Unique department numbers and descriptions
# - **_Products.csv_**: 49,688 Unique product ids, with description, aisle id, and department id
# - **_Orders.csv_**: 3,421,083 Unique order id, with user id, order number, order_dow, order_hour_of_day, days_since_prior_order, and eval_set indicating if the order is in train, prior, or test
# - **_Order_products_train.csv_**: Order id, product id, add to cart order, and reorder indicator
# - **_Order_products_prior.csv_**: Order id, product id, add to cart order, and reorder indicator

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Import and basic info
#
# **Output** - aisles, orders, products, departments, order_products_prior, order_products_train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import time
from datetime import datetime
import pickle
from collections import Counter
from itertools import combinations, groupby
import warnings
warnings.filterwarnings('ignore')

# %%
# Set default visualization parameters

CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'
color_list = [CB91_Blue, CB91_Pink, CB91_Green, CB91_Amber, CB91_Purple, CB91_Violet]
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)
sns.set_context("notebook", rc={"font.size":16, "axes.titlesize":20, "axes.labelsize":18})
sns.set(font='Franklin Gothic Book',
rc={'axes.axisbelow': False,
'axes.edgecolor': 'lightgrey',
# 'axes.edgecolor': 'white',
'axes.facecolor': 'None',
'axes.grid': False,
'axes.labelcolor': 'dimgrey',
# 'axes.labelcolor': 'white',
'axes.spines.right': False,
'axes.spines.top': False,
'axes.prop_cycle': plt.cycler(color=color_list),
'figure.facecolor': 'white',
'lines.solid_capstyle': 'round',
'patch.edgecolor': 'w',
'patch.force_edgecolor': True,
'text.color': 'dimgrey',
# 'text.color': 'white',    
'xtick.bottom': False,
'xtick.color': 'dimgrey',
# 'xtick.color': 'white',    
'xtick.direction': 'out',
'xtick.top': False,
'ytick.color': 'dimgrey',
# 'ytick.color': 'white',
'ytick.direction': 'out',
'ytick.left': False,
'ytick.right': False})
# %matplotlib inline

# NOTE: if you visualizations are too cluttered to read, try calling 'plt.gcf().autofmt_xdate()'!

# %% [markdown]
# ## Prepare Data for Market Basket Analysis

# %%
order_products_prior = pd.read_csv("Data/order_products__prior.csv")
order_products_train = pd.read_csv("Data/order_products__train.csv")
orders = pd.read_csv("Data/orders.csv")
grouped_users = pickle.load(open("Pickle/grouped_users.p", "rb"))
products_desc = pickle.load(open("Pickle/products_desc.p", "rb"))
merged_orders = pickle.load(open("Pickle/merged_orders.p", "rb"))
orders_test = orders[orders['eval_set']=='test']
clustered_users = pickle.load(open("Pickle/clustered_users.p", "rb"))

# %%
# I want to calculate the association rules by each cluster.  It will make the data smaller.
merged_orders = merged_orders.sort_values(['order_id','product_id'])
merged_orders.head()
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 18486555         1   112108    train             4          4
# 18486554         1   112108    train             4          4
# 18486558         1   112108    train             4          4
# 18486560         1   112108    train             4          4
# 18486557         1   112108    train             4          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 18486555                 10                     9.0       10246
# 18486554                 10                     9.0       11109
# 18486558                 10                     9.0       13176
# 18486560                 10                     9.0       22035
# 18486557                 10                     9.0       43633
#
#           add_to_cart_order  reordered  \
# 18486555                  3          0
# 18486554                  2          1
# 18486558                  6          0
# 18486560                  8          1
# 18486557                  5          1
#
#                                            product_name  aisle_id  \
# 18486555                          Organic Celery Hearts        83
# 18486554  Organic 4% Milk Fat Whole Milk Cottage Cheese       108
# 18486558                         Bag of Organic Bananas        24
# 18486560                    Organic Whole String Cheese        21
# 18486557           Lightly Smoked Sardines in Olive Oil        95
#
#           department_id                 aisle    department
# 18486555              4      fresh vegetables       produce
# 18486554             16  other creams cheeses    dairy eggs
# 18486558              4          fresh fruits       produce
# 18486560             16       packaged cheese    dairy eggs
# 18486557             15   canned meat seafood  canned goods

# %%
clustered_users.reset_index(inplace=True)

# %%
# Merging these to add the cluster to each order
clustered_orders = merged_orders.merge(clustered_users[['user_id','cluster']], on = 'user_id')

# %%
clustered_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0         1   112108    train             4          4                 10
# 1         1   112108    train             4          4                 10
# 2         1   112108    train             4          4                 10
# 3         1   112108    train             4          4                 10
# 4         1   112108    train             4          4                 10
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     9.0       10246                  3          0
# 1                     9.0       11109                  2          1
# 2                     9.0       13176                  6          0
# 3                     9.0       22035                  8          1
# 4                     9.0       43633                  5          1
#
#                                     product_name  aisle_id  department_id  \
# 0                          Organic Celery Hearts        83              4
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                         Bag of Organic Bananas        24              4
# 3                    Organic Whole String Cheese        21             16
# 4           Lightly Smoked Sardines in Olive Oil        95             15
#
#                   aisle    department  cluster
# 0      fresh vegetables       produce       12
# 1  other creams cheeses    dairy eggs       12
# 2          fresh fruits       produce       12
# 3       packaged cheese    dairy eggs       12
# 4   canned meat seafood  canned goods       12

# %% [markdown]
# ## Market Basket Analysis

# %%
# Returns frequency counts for items and item pairs
def freq(iterable):
    if type(iterable) == pd.core.series.Series:
        return iterable.value_counts().rename("freq")
    else: 
        return pd.Series(Counter(iterable)).rename("freq")

    
# Returns number of unique orders
def order_count(order_item):
    return len(set(order_item.index))


# Returns generator that yields item pairs, one at a time
def get_item_pairs(order_item):
    order_item = order_item.reset_index().to_numpy()
    for order_id, order_object in groupby(order_item, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
              
        for item_pair in combinations(item_list, 2):
            yield item_pair
            

# Returns frequency and support associated with item
def merge_item_stats(item_pairs, item_stats):
    return (item_pairs
                .merge(item_stats.rename(columns={'freq': 'freqA', 'support': 'supportA'}), 
                       left_on='item_A', right_index=True)
                .merge(item_stats.rename(columns={'freq': 'freqB', 'support': 'supportB'}), 
                       left_on='item_B', right_index=True))


# Returns name associated with item
def merge_item_name(rules, item_name):
    columns = ['itemA','itemB','freqAB','supportAB','freqA','supportA','freqB','supportB', 
               'confidenceAtoB','confidenceBtoA','lift']
    rules = (rules
                .merge(item_name.rename(columns={'item_name': 'itemA'}), left_on='item_A', right_on='item_id')
                .merge(item_name.rename(columns={'item_name': 'itemB'}), left_on='item_B', right_on='item_id'))

# %%
def association_rules(order_item, min_support):

    print("Starting number of order_item pairs: {:22d}".format(len(order_item)))


    # Calculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) 


    # Filter from order_item items below min support 
    qualifying_items       = item_stats[item_stats['support'] >= min_support].index
    order_item             = order_item[order_item.isin(qualifying_items)]

    print("Items with support >= {}: {:15d}".format(min_support, len(qualifying_items)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Filter from order_item orders with less than 2 items
    order_size             = freq(order_item.index)
    qualifying_orders      = order_size[order_size >= 2].index
    order_item             = order_item[order_item.index.isin(qualifying_orders)]

    print("Remaining orders with 2+ items: {:11d}".format(len(qualifying_orders)))
    print("Remaining order_item: {:21d}".format(len(order_item)))


    # Recalculate item frequency and support
    item_stats             = freq(order_item).to_frame("freq")
    item_stats['support']  = item_stats['freq'] / order_count(order_item) 


    # Get item pairs generator
    item_pair_gen          = get_item_pairs(order_item)


    # Calculate item pair frequency and support
    item_pairs              = freq(item_pair_gen).to_frame("freqAB")
    item_pairs['supportAB'] = item_pairs['freqAB'] / len(qualifying_orders)

    print("Item pairs: {:31d}".format(len(item_pairs)))


    # Filter from item_pairs those below min support
    item_pairs              = item_pairs[item_pairs['supportAB'] >= min_support]

    print("Item pairs with support >= {}: {:10d}\n".format(min_support, len(item_pairs)))


    # Create table of association rules and compute relevant metrics
    item_pairs = item_pairs.reset_index().rename(columns={'level_0': 'item_A', 'level_1': 'item_B'})
    item_pairs = merge_item_stats(item_pairs, item_stats)
    
    item_pairs['confidenceAtoB'] = item_pairs['supportAB'] / item_pairs['supportA']
    item_pairs['confidenceBtoA'] = item_pairs['supportAB'] / item_pairs['supportB']
    item_pairs['lift']           = item_pairs['supportAB'] / (item_pairs['supportA'] * item_pairs['supportB'])
    
    
    # Return association rules sorted by lift in descending order
    return item_pairs.sort_values('lift', ascending=False)

# %%
# separate order data by cluster and transform into expected format of group association function

cluster_orders = {}
for x in range(0,20):
    i = clustered_orders[clustered_orders['cluster'] == x]
    i = i[['order_id', 'product_id']]
    i = i.set_index('order_id')['product_id'].rename('item_id')
    cluster_orders[x] = i

# %%
# run each cluster series through association rule function and obtain association rules at item level

group_association_rules_dic = {}
for x in range(0,20):
    print('Cluster: ', x)
    group_association_rules_dic[x] = association_rules(cluster_orders[x],.0001)
# Out:
# Cluster:  0
# Starting number of order_item pairs:                 264115
# Items with support >= 0.0001:            8717
# Remaining order_item:                256351
# Remaining orders with 2+ items:       21637
# Remaining order_item:                255910
# Item pairs:                          808257
# Item pairs with support >= 0.0001:     178869
#
# Cluster:  1
# Starting number of order_item pairs:                7788280
# Items with support >= 0.0001:           10650
# Remaining order_item:               7187429
# Remaining orders with 2+ items:      746198
# Remaining order_item:               7152362
# Item pairs:                        10064495
# Item pairs with support >= 0.0001:      54507
#
# Cluster:  2
# Starting number of order_item pairs:                 754548
# Items with support >= 0.0001:            8319
# Remaining order_item:                736505
# Remaining orders with 2+ items:       52262
# Remaining order_item:                735544
# Item pairs:                         1756266
# Item pairs with support >= 0.0001:     276018
#
# Cluster:  3
# Starting number of order_item pairs:                1862032
# Items with support >= 0.0001:           15065
# Remaining order_item:               1754943
# Remaining orders with 2+ items:      143766
# Remaining order_item:               1752141
# Item pairs:                         6383258
# Item pairs with support >= 0.0001:      72327
#
# Cluster:  4
# Starting number of order_item pairs:                5951742
# Items with support >= 0.0001:            8735
# Remaining order_item:               5646989
# Remaining orders with 2+ items:      526738
# Remaining order_item:               5632223
# Item pairs:                         6933457
# Item pairs with support >= 0.0001:      87117
#
# Cluster:  5
# Starting number of order_item pairs:                 347793
# Items with support >= 0.0001:           12165
# Remaining order_item:                332363
# Remaining orders with 2+ items:       32990
# Remaining order_item:                331076
# Item pairs:                         1368605
# Item pairs with support >= 0.0001:     101697
#
# Cluster:  6
# Starting number of order_item pairs:                2797103
# Items with support >= 0.0001:            9451
# Remaining order_item:               2699856
# Remaining orders with 2+ items:      198973
# Remaining order_item:               2697436
# Item pairs:                         4833446
# Item pairs with support >= 0.0001:     174063
#
# Cluster:  7
# Starting number of order_item pairs:                 122688
# Items with support >= 0.0001:            9021
# Remaining order_item:                122688
# Remaining orders with 2+ items:        8798
# Remaining order_item:                122552
# Item pairs:                          521231
# Item pairs with support >= 0.0001:     521231
#
# Cluster:  8
# Starting number of order_item pairs:                1653446
# Items with support >= 0.0001:           11881
# Remaining order_item:               1606804
# Remaining orders with 2+ items:       89932
# Remaining order_item:               1606213
# Item pairs:                         4496908
# Item pairs with support >= 0.0001:     383194
#
# Cluster:  9
# Starting number of order_item pairs:                 237431
# Items with support >= 0.0001:            8642
# Remaining order_item:                229862
# Remaining orders with 2+ items:       27331
# Remaining order_item:                228286
# Item pairs:                          740441
# Item pairs with support >= 0.0001:     109262
#
# Cluster:  10
# Starting number of order_item pairs:                 455761
# Items with support >= 0.0001:            1982
# Remaining order_item:                445255
# Remaining orders with 2+ items:       73151
# Remaining order_item:                437462
# Item pairs:                          172361
# Item pairs with support >= 0.0001:      33197
#
# Cluster:  11
# Starting number of order_item pairs:                 315124
# Items with support >= 0.0001:            9743
# Remaining order_item:                307972
# Remaining orders with 2+ items:       26602
# Remaining order_item:                307350
# Item pairs:                         1124388
# Item pairs with support >= 0.0001:     196489
#
# Cluster:  12
# Starting number of order_item pairs:                5804594
# Items with support >= 0.0001:            8594
# Remaining order_item:               5172644
# Remaining orders with 2+ items:      729445
# Remaining order_item:               5071542
# Item pairs:                         6168742
# Item pairs with support >= 0.0001:      26943
#
# Cluster:  13
# Starting number of order_item pairs:                 563544
# Items with support >= 0.0001:           13234
# Remaining order_item:                541195
# Remaining orders with 2+ items:       39559
# Remaining order_item:                540498
# Item pairs:                         2309232
# Item pairs with support >= 0.0001:     309892
#
# Cluster:  14
# Starting number of order_item pairs:                2374227
# Items with support >= 0.0001:            8237
# Remaining order_item:               2288654
# Remaining orders with 2+ items:      188859
# Remaining order_item:               2285373
# Item pairs:                         3636379
# Item pairs with support >= 0.0001:     138346
#
# Cluster:  15
# Starting number of order_item pairs:                  72868
# Items with support >= 0.0001:            7499
# Remaining order_item:                 72868
# Remaining orders with 2+ items:        6701
# Remaining order_item:                 72518
# Item pairs:                          274107
# Item pairs with support >= 0.0001:     274107
#
# Cluster:  16
# Starting number of order_item pairs:                 507608
# Items with support >= 0.0001:            9570
# Remaining order_item:                495824
# Remaining orders with 2+ items:       35209
# Remaining order_item:                495387
# Item pairs:                         1684437
# Item pairs with support >= 0.0001:     267992
#
# Cluster:  17
# Starting number of order_item pairs:                 124542
# Items with support >= 0.0001:            5124
# Remaining order_item:                122554
# Remaining orders with 2+ items:       10987
# Remaining order_item:                122009
# Item pairs:                          348589
# Item pairs with support >= 0.0001:     137967
#
# Cluster:  18
# Starting number of order_item pairs:                1553965
# Items with support >= 0.0001:           13520
# Remaining order_item:               1421256
# Remaining orders with 2+ items:      159974
# Remaining order_item:               1412742
# Item pairs:                         4469825
# Item pairs with support >= 0.0001:      26478
#
# Cluster:  19
# Starting number of order_item pairs:                 267695
# Items with support >= 0.0001:            9644
# Remaining order_item:                258928
# Remaining orders with 2+ items:       24568
# Remaining order_item:                258039
# Item pairs:                          854966
# Item pairs with support >= 0.0001:     160001

# %%
# format item association rule dataframes and merge product names

for x in group_association_rules_dic:
    group_association_rules_dic[x] = group_association_rules_dic[x].merge(products_desc[['product_id','product_name']]
               .rename(columns = {'product_id':'item_A','product_name':'product_name_A'}), on = 'item_A')
    group_association_rules_dic[x] = group_association_rules_dic[x].merge(products_desc[['product_id','product_name']]
               .rename(columns = {'product_id':'item_B','product_name':'product_name_B'}), on = 'item_B')
    group_association_rules_dic[x] = group_association_rules_dic[x][['item_A','item_B','product_name_A',
                                                                    'product_name_B','freqAB','supportAB','freqA',
                                                                    'supportA','freqB','supportB','confidenceAtoB',
                                                                    'confidenceBtoA','lift']]

# %%
# example of association rule dataframe

x = group_association_rules_dic[5]
x.sort_values('lift', ascending = False)
# Out:
#        item_A  item_B                                    product_name_A  \
# 0        3786    7876                               Red Sugar Sprinkles
# 48      14413   39542  With Chicken & Veal in Meaty Juices Wet Dog Food
# 1        6296   17212                  Farmhouse-Style Sausage Scramble
# 696      8729   10199                  Natural Casing Beef Frankfurters
# 598      8964   13029                         Kickin’ BBQ Chopped Salad
# ...       ...     ...                                               ...
# 4327     3873   24852                             Mountain Spring Water
# 14863     196   13176                                              Soda
# 49995   13176   19348                            Bag of Organic Bananas
# 12345    8859   16797                              Natural Spring Water
# 11254   16797   21137                                      Strawberries
#
#                                           product_name_B  freqAB  supportAB  \
# 0                             Dark Green Sugar Sprinkles       4   0.000121
# 48     Canine Cuisine Prime Rib Flavor Gourmet Filets...       4   0.000121
# 1                                         Bacon Scramble       4   0.000121
# 696                         Watermelon Agave Frozen Pops       4   0.000121
# 598                Ready Pac Salad Santa Fe Caesar Bowls       5   0.000152
# ...                                                  ...     ...        ...
# 4327                                              Banana       6   0.000182
# 14863                             Bag of Organic Bananas       4   0.000121
# 49995                                      Fat Free Milk       4   0.000121
# 12345                                       Strawberries       4   0.000121
# 11254                               Organic Strawberries       4   0.000121
#
#        freqA  supportA  freqB  supportB  confidenceAtoB  confidenceBtoA  \
# 0          5  0.000152      4  0.000121        0.800000        1.000000
# 48         4  0.000121      5  0.000152        1.000000        0.800000
# 1          4  0.000121      5  0.000152        1.000000        0.800000
# 696        4  0.000121      6  0.000182        1.000000        0.666667
# 598        5  0.000152      6  0.000182        1.000000        0.833333
# ...      ...       ...    ...       ...             ...             ...
# 4327     209  0.006335   4115  0.124735        0.028708        0.001458
# 14863    445  0.013489   1291  0.039133        0.008989        0.003098
# 49995   1291  0.039133    512  0.015520        0.003098        0.007812
# 12345    359  0.010882   1950  0.059109        0.011142        0.002051
# 11254   1950  0.059109    463  0.014035        0.002051        0.008639
#
#               lift
# 0      6598.000000
# 48     6598.000000
# 1      6598.000000
# 696    5498.333333
# 598    5498.333333
# ...            ...
# 4327      0.230153
# 14863     0.229697
# 49995     0.199639
# 12345     0.188501
# 11254     0.146159
#
# [101697 rows x 13 columns]

# %%
# separate order data by cluster and transform into expected format of group association function at aisle level

cluster_aisle_orders = {}
for x in range(0,20):
    i = clustered_orders[clustered_orders['cluster'] == x]
    i = i.groupby(['order_id','aisle_id'])['product_id'].count().reset_index().set_index('order_id')['aisle_id'].rename('item_id')
    cluster_aisle_orders[x] = i

# %%
clustered_orders.groupby(['order_id','aisle_id'])['product_id'].count().reset_index().set_index('order_id')['aisle_id'].rename('item_id')
# Out:
# order_id
# 1           21
# 1           24
# 1           83
# 1           95
# 1          108
#           ...
# 3421083     52
# 3421083     74
# 3421083     78
# 3421083     92
# 3421083    117
# Name: item_id, Length: 24329222, dtype: int64

# %%
clustered_orders[clustered_orders['cluster'] == 5]['order_id'].nunique()
# Out:
# 34338

# %%
# run association function at aisle level

group_aisle_association_rules_dic = {}
for x in range(0,20):
    group_aisle_association_rules_dic[x] = association_rules(cluster_aisle_orders[x],.0001)
# Out:
# Starting number of order_item pairs:                 190556
# Items with support >= 0.0001:             134
# Remaining order_item:                190556
# Remaining orders with 2+ items:       21561
# Remaining order_item:                190018
# Item pairs:                            8092
# Item pairs with support >= 0.0001:       7159
#
# Starting number of order_item pairs:                5650431
# Items with support >= 0.0001:             134
# Remaining order_item:               5650431
# Remaining orders with 2+ items:      744957
# Remaining order_item:               5610317
# Item pairs:                            8906
# Item pairs with support >= 0.0001:       7324
#
# Starting number of order_item pairs:                 410177
# Items with support >= 0.0001:             133
# Remaining order_item:                410174
# Remaining orders with 2+ items:       51295
# Remaining order_item:                408131
# Item pairs:                            7223
# Item pairs with support >= 0.0001:       5201
#
# Starting number of order_item pairs:                1418848
# Items with support >= 0.0001:             134
# Remaining order_item:               1418848
# Remaining orders with 2+ items:      143604
# Remaining order_item:               1415613
# Item pairs:                            8847
# Item pairs with support >= 0.0001:       8147
#
# Starting number of order_item pairs:                4177720
# Items with support >= 0.0001:             134
# Remaining order_item:               4177720
# Remaining orders with 2+ items:      526247
# Remaining order_item:               4161057
# Item pairs:                            8837
# Item pairs with support >= 0.0001:       6657
#
# Starting number of order_item pairs:                 273476
# Items with support >= 0.0001:             134
# Remaining order_item:                273476
# Remaining orders with 2+ items:       32833
# Remaining order_item:                271971
# Item pairs:                            8521
# Item pairs with support >= 0.0001:       7938
#
# Starting number of order_item pairs:                1967768
# Items with support >= 0.0001:             134
# Remaining order_item:               1967768
# Remaining orders with 2+ items:      198837
# Remaining order_item:               1965017
# Item pairs:                            8663
# Item pairs with support >= 0.0001:       6860
#
# Starting number of order_item pairs:                  88466
# Items with support >= 0.0001:             134
# Remaining order_item:                 88466
# Remaining orders with 2+ items:        8760
# Remaining order_item:                 88292
# Item pairs:                            7569
# Item pairs with support >= 0.0001:       7569
#
# Starting number of order_item pairs:                1129572
# Items with support >= 0.0001:             134
# Remaining order_item:               1129572
# Remaining orders with 2+ items:       89898
# Remaining order_item:               1128891
# Item pairs:                            8757
# Item pairs with support >= 0.0001:       7900
#
# Starting number of order_item pairs:                 179363
# Items with support >= 0.0001:             134
# Remaining order_item:                179363
# Remaining orders with 2+ items:       26351
# Remaining order_item:                176758
# Item pairs:                            8221
# Item pairs with support >= 0.0001:       7406
#
# Starting number of order_item pairs:                 342174
# Items with support >= 0.0001:             123
# Remaining order_item:                342125
# Remaining orders with 2+ items:       71526
# Remaining order_item:                332577
# Item pairs:                            5853
# Item pairs with support >= 0.0001:       3478
#
# Starting number of order_item pairs:                 230075
# Items with support >= 0.0001:             134
# Remaining order_item:                230075
# Remaining orders with 2+ items:       26484
# Remaining order_item:                229316
# Item pairs:                            8317
# Item pairs with support >= 0.0001:       7672
#
# Starting number of order_item pairs:                4367609
# Items with support >= 0.0001:             134
# Remaining order_item:               4367609
# Remaining orders with 2+ items:      729657
# Remaining order_item:               4255944
# Item pairs:                            8901
# Item pairs with support >= 0.0001:       7031
#
# Starting number of order_item pairs:                 415669
# Items with support >= 0.0001:             134
# Remaining order_item:                415669
# Remaining orders with 2+ items:       39462
# Remaining order_item:                414838
# Item pairs:                            8760
# Item pairs with support >= 0.0001:       8382
#
# Starting number of order_item pairs:                1599614
# Items with support >= 0.0001:             134
# Remaining order_item:               1599614
# Remaining orders with 2+ items:      188763
# Remaining order_item:               1595950
# Item pairs:                            8552
# Item pairs with support >= 0.0001:       6526
#
# Starting number of order_item pairs:                  49185
# Items with support >= 0.0001:             134
# Remaining order_item:                 49185
# Remaining orders with 2+ items:        6511
# Remaining order_item:                 48645
# Item pairs:                            6567
# Item pairs with support >= 0.0001:       6567
#
# Starting number of order_item pairs:                 349190
# Items with support >= 0.0001:             134
# Remaining order_item:                349190
# Remaining orders with 2+ items:       35121
# Remaining order_item:                348644
# Item pairs:                            8126
# Item pairs with support >= 0.0001:       7071
#
# Starting number of order_item pairs:                  86072
# Items with support >= 0.0001:             129
# Remaining order_item:                 86072
# Remaining orders with 2+ items:       10900
# Remaining order_item:                 85429
# Item pairs:                            6423
# Item pairs with support >= 0.0001:       5625
#
# Starting number of order_item pairs:                1202860
# Items with support >= 0.0001:             134
# Remaining order_item:               1202860
# Remaining orders with 2+ items:      159580
# Remaining order_item:               1193113
# Item pairs:                            8860
# Item pairs with support >= 0.0001:       8178
#
# Starting number of order_item pairs:                 200397
# Items with support >= 0.0001:             134
# Remaining order_item:                200397
# Remaining orders with 2+ items:       24389
# Remaining order_item:                199302
# Item pairs:                            8108
# Item pairs with support >= 0.0001:       7107

# %%
# reformat cluster aisle assocation dataframes

for x in group_aisle_association_rules_dic:
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(products_desc[['aisle_id','aisle']]
               .rename(columns = {'aisle_id':'item_A','aisle':'aisle_name_A'}), on = 'item_A')
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(products_desc[['aisle_id','aisle']]
               .rename(columns = {'aisle_id':'item_B','aisle':'aisle_name_B'}), on = 'item_B')
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x][['item_A','item_B','aisle_name_A',
                                                                    'aisle_name_B','freqAB','supportAB','freqA',
                                                                    'supportA','freqB','supportB','confidenceAtoB',
                                                                    'confidenceBtoA','lift']]
    group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].rename(columns = {'item_A':'aisle_A','item_B':'aisle_B'})
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-67-fa726bfd1d4d> in <module>
#       4     group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(products_desc[['aisle_id','aisle']]
#       5                .rename(columns = {'aisle_id':'item_A','aisle':'aisle_name_A'}), on = 'item_A')
# ----> 6     group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x].merge(products_desc[['aisle_id','aisle']]
#       7                .rename(columns = {'aisle_id':'item_B','aisle':'aisle_name_B'}), on = 'item_B')
#       8     group_aisle_association_rules_dic[x] = group_aisle_association_rules_dic[x][['item_A','item_B','aisle_name_A',
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     666             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     667
# --> 668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
#     882             )
#     883         else:
# --> 884             (left_indexer, right_indexer) = self._get_join_indexers()
#     885
#     886             if self.right_index:
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(self)
#     860     def _get_join_indexers(self):
#     861         """ return the join indexers """
# --> 862         return _get_join_indexers(
#     863             self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#     864         )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in _get_join_indexers(left_keys, right_keys, sort, how, **kwargs)
#    1348     }[how]
#    1349
# -> 1350     return join_func(lkey, rkey, count, **kwargs)
#    1351
#    1352
#
# pandas\_libs\join.pyx in pandas._libs.join.inner_join()
#
# MemoryError: Unable to allocate 8.33 GiB for an array with shape (1117851371,) and data type int64

# %%
x = group_aisle_association_rules_dic[5].sort_values('lift',ascending = False)
x.sort_values('lift',ascending = False)

# %%
cluster_df['cluster'].value_counts() / cluster_df['cluster'].value_counts().sum()

# %%
for x in group_association_rules_dic:
    group_association_rules_dic[x].to_csv('group'+str(x)+'_item_rules.csv')

# %%
for x in group_aisle_association_rules_dic:
    group_aisle_association_rules_dic[x].to_csv('group'+str(x)+'_aisle_rules.csv')

# %% [markdown]
# ## Efficient Apriori

# %%
from efficient_apriori import apriori

# %%
transactions = [('eggs', 'bacon', 'soup'),
                ('eggs', 'bacon', 'apple'),
                ('soup', 'bacon', 'banana')]
itemsets, rules = apriori(transactions, min_support=0.5, min_confidence=1)
print(rules)  # [{eggs} -> {bacon}, {soup} -> {bacon}]
# Out:
# [{eggs} -> {bacon}, {soup} -> {bacon}]

# %%
transactions = [('eggs', 'bacon', 'soup'),
                ('eggs', 'bacon', 'apple'),
                ('soup', 'bacon', 'banana')]
itemsets, rules = apriori(transactions, min_support=0.2, min_confidence=1)

# Print out every rule with 2 items on the left hand side,
# 1 item on the right hand side, sorted by lift
rules_rhs = filter(lambda rule: len(rule.lhs) == 2 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift):
  print(rule)  # Prints the rule and its confidence, support, lift, ...
# Out:
# {eggs, soup} -> {bacon} (conf: 1.000, supp: 0.333, lift: 1.000, conv: 0.000)
# {apple, eggs} -> {bacon} (conf: 1.000, supp: 0.333, lift: 1.000, conv: 0.000)
# {banana, soup} -> {bacon} (conf: 1.000, supp: 0.333, lift: 1.000, conv: 0.000)
# {apple, bacon} -> {eggs} (conf: 1.000, supp: 0.333, lift: 1.500, conv: 333333333.333)
# {bacon, banana} -> {soup} (conf: 1.000, supp: 0.333, lift: 1.500, conv: 333333333.333)

# %%
transactions = [('eggs', 'bacon', 'soup'),
                ('eggs', 'bacon', 'apple'),
                ('soup', 'bacon', 'banana')]
itemsets, rules = apriori(transactions, output_transaction_ids=True)
print(itemsets)
# {1: {('bacon',): ItemsetCount(itemset_count=3, members={0, 1, 2}), ...
# Out:
# {1: {('soup',): ItemsetCount(itemset_count=2, members={0, 2}), ('bacon',): ItemsetCount(itemset_count=3, members={0, 1, 2}), ('eggs',): ItemsetCount(itemset_count=2, members={0, 1})}, 2: {('bacon', 'eggs'): ItemsetCount(itemset_count=2, members={0, 1}), ('bacon', 'soup'): ItemsetCount(itemset_count=2, members={0, 2})}}
